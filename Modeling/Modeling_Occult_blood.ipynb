# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../Data/dataset.csv')
dataset = dataset[['Protein', 'Leukocyte', 'SG', 'Bilirubin', 'Acidity', 'Nitrite',
                   'Urobilinogen','Occult_blood', 'Ketone_body', 'Glucose']]

dataset.head(3)
# Out:
#    Protein  Leukocyte     SG  Bilirubin  Acidity  Nitrite  Urobilinogen  \
# 0        1        119  1.020        0.1      5.0   103842           0.7
# 1        4        106  1.020        0.0      5.0   108098           0.7
# 2        6        657  1.016        0.1      5.0    27515           0.7
#
#    Occult_blood  Ketone_body  Glucose
# 0             3            1       16
# 1             2            1       65
# 2            40            3       79

# %%
dataset.corr()['Occult_blood'].abs().sort_values(ascending=False)
# Out:
# Occult_blood    1.000000
# Leukocyte       0.183746
# SG              0.149275
# Urobilinogen    0.131899
# Ketone_body     0.118204
# Protein         0.103824
# Acidity         0.096756
# Glucose         0.076694
# Nitrite         0.027737
# Bilirubin       0.007515
# Name: Occult_blood, dtype: float64

# %%
# Selecing columns

dataset = dataset[['Protein', 'Leukocyte', 'SG', 'Bilirubin', 'Acidity', 'Nitrite',
                   'Urobilinogen', 'Ketone_body', 'Glucose', 'Occult_blood']]

dataset.head(3)
# Out:
#    Protein  Leukocyte     SG  Bilirubin  Acidity  Nitrite  Urobilinogen  \
# 0        1        119  1.020        0.1      5.0   103842           0.7
# 1        4        106  1.020        0.0      5.0   108098           0.7
# 2        6        657  1.016        0.1      5.0    27515           0.7
#
#    Ketone_body  Glucose  Occult_blood
# 0            1       16             3
# 1            1       65             2
# 2            3       79            40

# %%
dataset.shape
# Out:
# (74337, 10)

# %%
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

X.shape, y.shape
# Out:
# ((74337, 9), (74337,))

# %% [markdown]
# # Train, Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2022)

X_train.shape, X_test.shape
# Out:
# ((59469, 9), (14868, 9))

# %%
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=2022)

# X_train.shape, X_val.shape
# Out:
# ((47575, 3), (11894, 3))

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
# X_val = ss.transform(X_val)
X_test = ss.transform(X_test)

# %%
X_train[:5, :]
# Out:
# array([[-0.4568329 , -0.53870365, -0.59688789,  0.19038558,  0.27419382,
#          0.67809502, -0.28070469, -0.52379031, -0.6161976 ],
#        [-0.44443037, -0.48245593, -0.34512929, -0.54462091, -0.87977981,
#          0.0413241 , -0.11140888, -0.55737155, -0.55352856],
#        [-0.48411847, -0.55628106, -1.60392227,  0.55788882, -0.87977981,
#          1.91393744,  0.05788693, -0.49020907, -0.65403552],
#        [-0.44443037, -0.48245593,  0.91366369, -0.54462091, -0.87977981,
#          0.0413241 , -0.11140888,  1.96122139, -0.55352856],
#        [ 0.03926827, -0.40863081, -0.84864648,  0.55788882, -0.49512194,
#          1.32531027, -0.22427276, -0.55737155, -0.60792056]])

# %% [markdown]
# # Modeling

# %% [markdown]
# ## 1. RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, KFold

# %%
params = {
    'n_estimators' : range(100, 200, 5),
    'verbose' : [True]
}

# %%
rfr = RandomForestRegressor(n_jobs=8, random_state=2022)

# %%
# 0값 확인
# 0값 존재 -> MAPE 사용 불가 (실제 y값으로 나누기 때문(y > 0 필수))

len(dataset.loc[dataset.Occult_blood == 0])
# Out:
# 2284

# %%
kfold = KFold(10, shuffle=True, random_state=2022)

# %% [markdown]
# ### Learning

# %%
grid = GridSearchCV(rfr, params, n_jobs=8, cv=kfold, refit=True)
grid.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 195 out of 195 | elapsed:    4.9s finished
# GridSearchCV(cv=KFold(n_splits=10, random_state=2022, shuffle=True),
#              estimator=RandomForestRegressor(n_jobs=8, random_state=2022),
#              n_jobs=8,
#              param_grid={'n_estimators': range(100, 200, 5), 'verbose': [True]})

# %%
grid.best_params_
# Out:
# {'n_estimators': 195, 'verbose': True}

# %%
y_pred = grid.best_estimator_.predict(X_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 195 out of 195 | elapsed:    0.0s finished

# %% [markdown]
# ### Evaluating

# %%
from sklearn.metrics import mean_absolute_percentage_error, \
                            mean_absolute_error, mean_squared_error

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 6633858504125487.0

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 131.281393666665

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 188.071182734865

# %%
# Test_data 14868개 중 MAE 값이 131.28139 -> data 하나당 평균 오차 약 0.00882

print('Mean:', y_test.mean())
print('Meidan:', y_test.median())
print('Max:', y_test.max())
print('Min:', y_test.min())
print('y_test length:', len(y_test))
print('Average Error: ', mean_absolute_error(y_test, y_pred) / len(y_test))
# Out:
# Mean: 160.5193032015066
# Meidan: 37.0
# Max: 749
# Min: 0
# y_test length: 14868
# Average Error:  0.008829795108061944

# %% [markdown]
# ### Comparising y_pred, y_result

# %%
comparison = pd.DataFrame({'prediction' : y_pred, 'result' : y_test.values.ravel()})

# %%
comparison
# Out:
#        prediction  result
# 0      228.272328     212
# 1      272.219697     408
# 2      246.955558     490
# 3      224.333895       4
# 4        1.989744       2
# ...           ...     ...
# 14863  272.219697     131
# 14864  211.418277     606
# 14865   62.008547      38
# 14866  378.003599     536
# 14867   32.476923       1
#
# [14868 rows x 2 columns]

# %% [markdown]
# ### Saving Model

# %%
import pickle

# %%
saved_model = pickle.dump(grid.best_estimator_, open('../Model/{0}_RFT_n_{1}.pkl' \
    .format(dataset.columns[-1], grid.best_params_.get('n_estimators')), 'wb'),
                          protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Loading Model

# %%
loaded_model = pickle.load(open('../Model/{0}_RFT_n_195.pkl' \
    .format(dataset.columns[-1]), 'rb'))

# %%
y_pred = loaded_model.predict(X_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 195 out of 195 | elapsed:    0.0s finished

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 131.281393666665

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 188.071182734865

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(12, 10))

plt.plot(y_test.values.ravel(), label='y_test')
plt.plot(y_pred, label='y_pred')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 10))

plt.plot(y_test.values.ravel().reshape(-1)[:100], label='y_test')
plt.plot(y_pred.reshape(-1)[:100], label='y_pred')

plt.legend()
plt.show()
